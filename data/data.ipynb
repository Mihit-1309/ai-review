# %%
import pandas as pd

# %%
df = pd.read_csv('datas.csv')

# %%
df.head()
# Out:
#                                         review_title  \
# 0                                            Perfect
# 1                      Always work in my picky Epson
# 2                           ALWAYS CONSISTENTLY GOOD
# 3  Swift Ink is the best remanufactured ink on th...
# 4                                        Great value
#
#                                          review_text  rating  \
# 0  It was recognized and is now working perfectly...       5
# 1  Excellent company to work with, best customer ...       5
# 2  I've bought from Swift for years and have save...       5
# 3           The XL cartridge lasts a very long time.       5
# 4  I been using swift ink for several years and I...       5
#
#                 review_date        reviewer_name  product_id  \
# 0  2026-01-05T19:06:53.028Z  Thanasis Mitsolides      6853.0
# 1  2025-12-31T14:58:52.663Z     w. sharon prator      6230.0
# 2  2025-12-30T01:43:43.153Z          Mike Somers      6362.0
# ...

# %%
df['product_id'].value_counts()
# Out:
# product_id
# 10210.0    243
# 5027.0     167
# 5617.0     165
# 4657.0     159
# 5023.0     159
#           ...
# 5671.0       1
# 2493.0       1
# 2867.0       1
# 4833.0       1
# 10149.0      1
# Name: count, Length: 1252, dtype: int64

# %%
df['WSID'].value_counts()
# Out:
# WSID
# 1gm0fkmh7pht84    13468
# 1eqwkmhcf9qec       992
# Name: count, dtype: int64

# %%
df['WSID'].nunique()
# Out:
# 1

# %%
df['review_title'].isnull().sum()
# Out:
# 9533

# %%
df['WSID'] = "1gm0fkmh7pht84"

# %%
df.head()
# Out:
#                                         review_title  \
# 0                                            Perfect
# 1                      Always work in my picky Epson
# 2                           ALWAYS CONSISTENTLY GOOD
# 3  Swift Ink is the best remanufactured ink on th...
# 4                                        Great value
#
#                                          review_text  rating  \
# 0  It was recognized and is now working perfectly...       5
# 1  Excellent company to work with, best customer ...       5
# 2  I've bought from Swift for years and have save...       5
# 3           The XL cartridge lasts a very long time.       5
# 4  I been using swift ink for several years and I...       5
#
#                 review_date        reviewer_name  product_id  \
# 0  2026-01-05T19:06:53.028Z  Thanasis Mitsolides      6853.0
# 1  2025-12-31T14:58:52.663Z     w. sharon prator      6230.0
# 2  2025-12-30T01:43:43.153Z          Mike Somers      6362.0
# ...

# %%
df.to_csv('datas.csv',index = False)

# %%
import pandas as pd

df1 = pd.read_csv("store1.csv")
df2 = pd.read_csv("store2.csv")

merged = pd.concat([df1, df2], ignore_index=True)

merged.to_csv("datas.csv", index=False)

# %%
df.shape
# Out:
# (14460, 9)

# %%
df[['review_text','rating','product_id']].duplicated().sum()
# Out:
# 520
